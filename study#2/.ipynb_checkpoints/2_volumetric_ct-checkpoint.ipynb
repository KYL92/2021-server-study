# %%
import numpy as np
import torch
torch.set_printoptions(edgeitems=2, threshold=50)

# %%
# Digital Imaging and Communications in Medicine (DICOM)
import imageio

dir_path = "../data/study#2/volumetric-dicom/2-LUNG 3.0  B70f-04083"
vol_arr = imageio.volread(dir_path, 'DICOM')
vol_arr.shape
# Out:
# Reading DICOM (examining files): 1/99 files (1.0%99/99 files (100.0%)
#   Found 1 correct series.
# Reading DICOM (loading data): 99/99  (100.0%)
# (99, 512, 512)

# %%
vol = torch.from_numpy(vol_arr).float() # numpy to tensor 부터 캐스팅까지 한번에 수행
vol = torch.unsqueeze(vol, 0)
vol.shape
# Out:
# torch.Size([1, 99, 512, 512])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.imshow(vol_arr[50])

# %%
f, axarr = plt.subplots(3,3, figsize=(15, 15))
axarr[0,0].imshow(vol_arr[50])
axarr[0,1].imshow(vol_arr[55])
axarr[0,2].imshow(vol_arr[60])
axarr[1,0].imshow(vol_arr[70])
axarr[1,1].imshow(vol_arr[75])
axarr[1,2].imshow(vol_arr[80])
axarr[2,0].imshow(vol_arr[85])
axarr[2,1].imshow(vol_arr[90])
axarr[2,2].imshow(vol_arr[95])
