# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from tensorboardX import SummaryWriter

# GPU 자원 사용확인
devices_id = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.cuda.set_device(
    devices_id
)  # fix bug for `ERROR: all tensors must be on devices[0]`

# Create Tensorboard SummaryWriter instance
writer = SummaryWriter('./summary/with_CNN')

# Step 1. Load Dataset
train_dataset = dsets.MNIST(
    root="../data", train=True, transform=transforms.ToTensor(), download=False
)
test_dataset = dsets.MNIST(
    root="../data", train=False, transform=transforms.ToTensor(), download=False
)

# Step 2. Make Dataset Iterable
batch_size = 100
train_loader = torch.utils.data.DataLoader(
    dataset=train_dataset, batch_size=batch_size, shuffle=True
)
test_loader = torch.utils.data.DataLoader(
    dataset=test_dataset, batch_size=batch_size, shuffle=False
)

# %%
# Step 3. Create Model Class
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.mp = nn.MaxPool2d(2)
        self.fc = nn.Linear(320, 10)

    def forward(self, x):
        in_size = x.size(0)
        x = F.relu(self.mp(self.conv1(x)))
        x = F.relu(self.mp(self.conv2(x)))
        x = x.view(in_size, -1)  # flatten the tensor
        outputs = self.fc(x)
        return outputs

# %%
epochs = 30
lr_rate = 0.01

# Step 4. Instantiate Model Class
model = CNN()
if devices_id == type([]):  # -> GPU
    model = nn.DataParallel(model, device_ids=devices_id).cuda()
else:
    model = nn.DataParallel(model, device_ids=[devices_id]).cuda()

# Step 5. Instantiate Loss Class
criterion = torch.nn.CrossEntropyLoss()  # computes softmax and then the cross entropy
# Step 6. Instantiate Optimizer Class
optimizer = torch.optim.SGD(model.parameters(), lr=lr_rate)

# %%
# Step 7. Train Model

# 임의의 학습 이미지를 가져옵니다
dataiter = iter(train_loader)
images, _ = dataiter.next()
writer.add_graph(model, images)

loss = 0
total_iter = 0

for epoch in range(int(epochs)):
    iter = 0
    for i, (images, labels) in enumerate(train_loader):
        images = images.to(devices_id)
        labels = labels.to(devices_id)
        optimizer.zero_grad()
        outputs = model(images)
        # Calc loss
        loss = criterion(outputs, labels)
        # Back-propagation
        loss.backward()
        # Updating wegihts
        optimizer.step()

        total_iter += 1
        writer.add_scalar('Train/Loss', loss, total_iter)

        iter += 1
        if iter % 200 == 0:
            # calculate Accuracy
            correct = 0
            total = 0
            for images, labels in test_loader:
                images = images.to(devices_id)
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                # for gpu, bring the predicted and labels back to cpu fro python operations to work
                predicted = predicted.cpu()
                correct += (predicted == labels).sum()
            accuracy = 100 * correct / total
            print(
                f"[Epoch {epoch}] [Iteration: {i}/{len(train_loader)}] [Loss: {loss.item():.3f}] [Accuracy: {accuracy:.2f}]"
            )

writer.close()
# Out:
# [Epoch 0] [Iteration: 199/600] [Loss: 2.163] [Accuracy: 41.72]
# [Epoch 0] [Iteration: 399/600] [Loss: 0.678] [Accuracy: 86.09]
# [Epoch 0] [Iteration: 599/600] [Loss: 0.389] [Accuracy: 88.87]
# [Epoch 1] [Iteration: 199/600] [Loss: 0.318] [Accuracy: 91.23]
# [Epoch 1] [Iteration: 399/600] [Loss: 0.212] [Accuracy: 92.42]
# [Epoch 1] [Iteration: 599/600] [Loss: 0.295] [Accuracy: 93.55]
# [Epoch 2] [Iteration: 199/600] [Loss: 0.274] [Accuracy: 93.91]
# [Epoch 2] [Iteration: 399/600] [Loss: 0.231] [Accuracy: 93.86]
# [Epoch 2] [Iteration: 599/600] [Loss: 0.160] [Accuracy: 94.48]
# [Epoch 3] [Iteration: 199/600] [Loss: 0.157] [Accuracy: 95.03]
# [Epoch 3] [Iteration: 399/600] [Loss: 0.216] [Accuracy: 95.46]
# [Epoch 3] [Iteration: 599/600] [Loss: 0.219] [Accuracy: 95.49]
# [Epoch 4] [Iteration: 199/600] [Loss: 0.157] [Accuracy: 95.71]
# [Epoch 4] [Iteration: 399/600] [Loss: 0.113] [Accuracy: 96.30]
# [Epoch 4] [Iteration: 599/600] [Loss: 0.064] [Accuracy: 96.25]
# [Epoch 5] [Iteration: 199/600] [Loss: 0.119] [Accuracy: 96.28]
# [Epoch 5] [Iteration: 399/600] [Loss: 0.101] [Accuracy: 96.64]
# [Epoch 5] [Iteration: 599/600] [Loss: 0.209] [Accuracy: 96.73]
# [Epoch 6] [Iteration: 199/600] [Loss: 0.070] [Accuracy: 96.82]
# [Epoch 6] [Iteration: 399/600] [Loss: 0.107] [Accuracy: 96.84]
# [Epoch 6] [Iteration: 599/600] [Loss: 0.266] [Accuracy: 96.84]
# [Epoch 7] [Iteration: 199/600] [Loss: 0.106] [Accuracy: 96.98]
# [Epoch 7] [Iteration: 399/600] [Loss: 0.102] [Accuracy: 97.25]
# [Epoch 7] [Iteration: 599/600] [Loss: 0.041] [Accuracy: 97.18]
# [Epoch 8] [Iteration: 199/600] [Loss: 0.056] [Accuracy: 97.38]
# [Epoch 8] [Iteration: 399/600] [Loss: 0.129] [Accuracy: 97.35]
# [Epoch 8] [Iteration: 599/600] [Loss: 0.051] [Accuracy: 97.51]
# [Epoch 9] [Iteration: 199/600] [Loss: 0.069] [Accuracy: 97.50]
# [Epoch 9] [Iteration: 399/600] [Loss: 0.049] [Accuracy: 97.49]
# [Epoch 9] [Iteration: 599/600] [Loss: 0.103] [Accuracy: 97.67]
# [Epoch 10] [Iteration: 199/600] [Loss: 0.059] [Accuracy: 97.59]
# [Epoch 10] [Iteration: 399/600] [Loss: 0.083] [Accuracy: 97.64]
# [Epoch 10] [Iteration: 599/600] [Loss: 0.044] [Accuracy: 97.77]
# [Epoch 11] [Iteration: 199/600] [Loss: 0.030] [Accuracy: 97.70]
# [Epoch 11] [Iteration: 399/600] [Loss: 0.046] [Accuracy: 97.83]
# [Epoch 11] [Iteration: 599/600] [Loss: 0.039] [Accuracy: 97.75]
# [Epoch 12] [Iteration: 199/600] [Loss: 0.024] [Accuracy: 97.88]
# [Epoch 12] [Iteration: 399/600] [Loss: 0.067] [Accuracy: 97.68]
# [Epoch 12] [Iteration: 599/600] [Loss: 0.141] [Accuracy: 97.73]
# [Epoch 13] [Iteration: 199/600] [Loss: 0.041] [Accuracy: 97.96]
# [Epoch 13] [Iteration: 399/600] [Loss: 0.109] [Accuracy: 97.78]
# [Epoch 13] [Iteration: 599/600] [Loss: 0.134] [Accuracy: 97.92]
# [Epoch 14] [Iteration: 199/600] [Loss: 0.070] [Accuracy: 97.96]
# [Epoch 14] [Iteration: 399/600] [Loss: 0.058] [Accuracy: 98.03]
# [Epoch 14] [Iteration: 599/600] [Loss: 0.060] [Accuracy: 98.04]
# [Epoch 15] [Iteration: 199/600] [Loss: 0.050] [Accuracy: 98.09]
# [Epoch 15] [Iteration: 399/600] [Loss: 0.036] [Accuracy: 97.98]
# [Epoch 15] [Iteration: 599/600] [Loss: 0.031] [Accuracy: 98.24]
# [Epoch 16] [Iteration: 199/600] [Loss: 0.019] [Accuracy: 98.07]
# [Epoch 16] [Iteration: 399/600] [Loss: 0.044] [Accuracy: 98.13]
# [Epoch 16] [Iteration: 599/600] [Loss: 0.053] [Accuracy: 98.24]
# [Epoch 17] [Iteration: 199/600] [Loss: 0.118] [Accuracy: 98.07]
# [Epoch 17] [Iteration: 399/600] [Loss: 0.046] [Accuracy: 98.29]
# [Epoch 17] [Iteration: 599/600] [Loss: 0.026] [Accuracy: 98.16]
# [Epoch 18] [Iteration: 199/600] [Loss: 0.049] [Accuracy: 98.22]
# [Epoch 18] [Iteration: 399/600] [Loss: 0.017] [Accuracy: 98.31]
# [Epoch 18] [Iteration: 599/600] [Loss: 0.140] [Accuracy: 98.41]
# [Epoch 19] [Iteration: 199/600] [Loss: 0.030] [Accuracy: 98.20]
# [Epoch 19] [Iteration: 399/600] [Loss: 0.042] [Accuracy: 98.12]
# [Epoch 19] [Iteration: 599/600] [Loss: 0.089] [Accuracy: 98.29]
# [Epoch 20] [Iteration: 199/600] [Loss: 0.015] [Accuracy: 98.15]
# [Epoch 20] [Iteration: 399/600] [Loss: 0.070] [Accuracy: 98.23]
# [Epoch 20] [Iteration: 599/600] [Loss: 0.043] [Accuracy: 98.40]
# [Epoch 21] [Iteration: 199/600] [Loss: 0.039] [Accuracy: 98.37]
# [Epoch 21] [Iteration: 399/600] [Loss: 0.043] [Accuracy: 98.32]
# [Epoch 21] [Iteration: 599/600] [Loss: 0.102] [Accuracy: 98.41]
# [Epoch 22] [Iteration: 199/600] [Loss: 0.129] [Accuracy: 98.46]
# [Epoch 22] [Iteration: 399/600] [Loss: 0.035] [Accuracy: 98.43]
# [Epoch 22] [Iteration: 599/600] [Loss: 0.028] [Accuracy: 98.39]
# [Epoch 23] [Iteration: 199/600] [Loss: 0.079] [Accuracy: 98.21]
# [Epoch 23] [Iteration: 399/600] [Loss: 0.110] [Accuracy: 98.27]
# [Epoch 23] [Iteration: 599/600] [Loss: 0.078] [Accuracy: 98.53]
# [Epoch 24] [Iteration: 199/600] [Loss: 0.174] [Accuracy: 98.35]
# [Epoch 24] [Iteration: 399/600] [Loss: 0.075] [Accuracy: 98.36]
# [Epoch 24] [Iteration: 599/600] [Loss: 0.085] [Accuracy: 98.43]
# [Epoch 25] [Iteration: 199/600] [Loss: 0.096] [Accuracy: 98.41]
# [Epoch 25] [Iteration: 399/600] [Loss: 0.039] [Accuracy: 98.52]
# [Epoch 25] [Iteration: 599/600] [Loss: 0.011] [Accuracy: 98.46]
# [Epoch 26] [Iteration: 199/600] [Loss: 0.019] [Accuracy: 98.55]
# [Epoch 26] [Iteration: 399/600] [Loss: 0.055] [Accuracy: 98.47]
# [Epoch 26] [Iteration: 599/600] [Loss: 0.029] [Accuracy: 98.51]
# [Epoch 27] [Iteration: 199/600] [Loss: 0.029] [Accuracy: 98.46]
# [Epoch 27] [Iteration: 399/600] [Loss: 0.030] [Accuracy: 98.54]
# [Epoch 27] [Iteration: 599/600] [Loss: 0.021] [Accuracy: 98.51]
# [Epoch 28] [Iteration: 199/600] [Loss: 0.160] [Accuracy: 98.51]
# [Epoch 28] [Iteration: 399/600] [Loss: 0.031] [Accuracy: 98.46]
# [Epoch 28] [Iteration: 599/600] [Loss: 0.012] [Accuracy: 98.47]
# [Epoch 29] [Iteration: 199/600] [Loss: 0.007] [Accuracy: 98.41]
# [Epoch 29] [Iteration: 399/600] [Loss: 0.066] [Accuracy: 98.50]
# [Epoch 29] [Iteration: 599/600] [Loss: 0.036] [Accuracy: 98.53]
